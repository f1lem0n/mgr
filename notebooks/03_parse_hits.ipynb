# %%
from Bio import Entrez, SeqIO
from Bio.SeqRecord import SeqRecord
from io import StringIO
import pandas as pd

# %%
Entrez.email = "hajdylaf@gmail.com"
colnames = ["query", "subject", "identity", "length", "mismatches", "gaps", "qstart", "qend", "sstart", "send", "evalue", "bitscore"]

# %%
def transform_df(df):
    df = df[df["identity"] != 100]
    new_df = []
    for query_id in df["query"].unique():
        new_df.append(df[df["query"] == query_id][:10])
    df = pd.concat(new_df)
    return df

def get_nn_homologs(df):
    homologs = {}
    fetched = {}
    for _, row in df.iterrows():
        print(f"\nQUERY: {row.query}")
        print(f"SUBJECT: {row.subject}")

        if row.subject not in fetched:
            print("Fetching...")
            with Entrez.efetch(
                db="nucleotide", id=row.subject, rettype="fasta", retmode="text"
            ) as handle:
                rec = list(SeqIO.parse(handle, "fasta"))[0]
            fetched[row.subject] = rec
        else:
            rec = fetched[row.subject]

        if not rec.seq:
            print("No sequence found for", row.subject)
            continue

        seq = rec.seq[row.sstart - 1:row.send]
        sid = f"{row.subject}.{row.sstart}:{row.send}"
        new = SeqRecord(seq=seq, id=sid, description=rec.description)

        if not new.seq:
            print("No sequence found for", sid)
            continue

        if row.query not in homologs:
            homologs[row.query] = [new]
        else:
            homologs[row.query] += [new]

        print(f"Saved as {new.id}")
    return homologs

# %%
df = pd.read_csv("../output/structures/rRNA/blastn-hits.csv", header=None, names=colnames)
df = transform_df(df)

homologs = get_nn_homologs(df)

for query in homologs:
    with open(f"../output/structures/rRNA/{query}/seqdump_nn.txt", "w") as f:
        SeqIO.write(homologs[query], f, "fasta")
# Out:
# QUERY: 15S_rRNA
# SUBJECT: MW367978.1
# Fetching...
# Saved as MW367978.1.32029:33673
#
# QUERY: 15S_rRNA
# SUBJECT: MW367978.1
# No sequence found for MW367978.1.78796:77193
#
# QUERY: 15S_rRNA
# SUBJECT: NC_059893.1
# Fetching...
# Saved as NC_059893.1.32554:34198
#
# QUERY: 15S_rRNA
# SUBJECT: AF114935.1
# Fetching...
# Saved as AF114935.1.247:1890
#
# QUERY: 15S_rRNA
# SUBJECT: LT986467.1
# Fetching...
# Saved as LT986467.1.70425:72044
#
# QUERY: 15S_rRNA
# SUBJECT: CP020309.1
# Fetching...
# Saved as CP020309.1.61710:63332
#
# QUERY: 15S_rRNA
# SUBJECT: NC_031514.1
# Fetching...
# Saved as NC_031514.1.33806:35428
#
# QUERY: 15S_rRNA
# SUBJECT: AF114941.1
# Fetching...
# Saved as AF114941.1.380:2002
#
# QUERY: 15S_rRNA
# SUBJECT: KY287661.1
# Fetching...
# Saved as KY287661.1.32726:34343
#
# QUERY: 15S_rRNA
# SUBJECT: KY287653.1
# Fetching...
# Saved as KY287653.1.33600:35218
#
# QUERY: 21S_rRNA
# SUBJECT: NC_059893.1
# Saved as NC_059893.1.2:3303
#
# QUERY: 21S_rRNA
# ...

# %%
df = pd.read_csv("../output/structures/tRNA/blastn-hits.csv", header=None, names=colnames)
df = transform_df(df)

homologs = get_nn_homologs(df)

for query in homologs:
    with open(f"../output/structures/tRNA/{query}/seqdump_nn.txt", "w") as f:
        SeqIO.write(homologs[query], f, "fasta")
# Out:
# QUERY: RPM1
# SUBJECT: CP081986.2
# Fetching...
# No sequence found for CP081986.2.46306:45991
#
# QUERY: RPM1
# SUBJECT: CP081986.2
# No sequence found for CP081986.2.61844:61531
#
# QUERY: RPM1
# SUBJECT: CP081986.2
# Saved as CP081986.2.29139:29505
#
# QUERY: RPM1
# SUBJECT: KP712786.1
# Fetching...
# Saved as KP712786.1.43027:43227
#
# QUERY: RPM1
# SUBJECT: NC_059893.1
# Fetching...
# No sequence found for NC_059893.1.77580:77276
#
# QUERY: RPM1
# SUBJECT: NC_059893.1
# Saved as NC_059893.1.17556:17865
#
# QUERY: RPM1
# SUBJECT: NC_059893.1
# Saved as NC_059893.1.60764:60917
#
# QUERY: RPM1
# SUBJECT: NC_059893.1
# No sequence found for NC_059893.1.35259:34990
#
# QUERY: RPM1
# SUBJECT: MW367978.1
# Fetching...
# Saved as MW367978.1.17031:17340
#
# QUERY: RPM1
# SUBJECT: MW367978.1
# No sequence found for MW367978.1.34734:34465
#
# QUERY: tA(AGC)D
# SUBJECT: CP049010.1
# Fetching...
# No sequence found for CP049010.1.782134:782062
#
# QUERY: tA(AGC)D
# SUBJECT: CP125613.1
# ...

# %%
df = pd.read_csv("../output/structures/mRNA/blastn-hits.csv", header=None, names=colnames)
df = transform_df(df)

homologs = get_nn_homologs(df)

for query in homologs:
    with open(f"../output/structures/mRNA/{query}/seqdump_nn.txt", "w") as f:
        SeqIO.write(homologs[query], f, "fasta")
# Out:
# QUERY: YAL053W
# SUBJECT: EF058500.1
# Fetching...
# Saved as EF058500.1.1:2351
#
# QUERY: YAL053W
# SUBJECT: CP048983.1
# Fetching...
# Saved as CP048983.1.36944:39295
#
# QUERY: YAL053W
# SUBJECT: CP111106.1
# Fetching...
# Saved as CP111106.1.298107:300458
#
# QUERY: YAL053W
# SUBJECT: CP125584.1
# Fetching...
# Saved as CP125584.1.40562:42913
#
# QUERY: YAL053W
# SUBJECT: CP125567.1
# Fetching...
# Saved as CP125567.1.38919:41270
#
# QUERY: YAL053W
# SUBJECT: CP125550.1
# Fetching...
# Saved as CP125550.1.41394:43745
#
# QUERY: YAL053W
# SUBJECT: CP125533.1
# Fetching...
# Saved as CP125533.1.40683:43034
#
# QUERY: YAL053W
# SUBJECT: CP125448.1
# Fetching...
# Saved as CP125448.1.107908:110259
#
# QUERY: YAL053W
# SUBJECT: CP125431.1
# Fetching...
# Saved as CP125431.1.26318:28669
#
# QUERY: YAL053W
# SUBJECT: XM_033908530.1
# Fetching...
# Saved as XM_033908530.1.1:2352
#
# QUERY: YBL004W
# SUBJECT: CP048984.1
# Fetching...
# Saved as CP048984.1.221846:229317
#
# QUERY: YBL004W
# ...

# %%
colnames = ["query", "subject", "identity", "length", "mismatches", "gaps", "qstart", "qend", "sstart", "send", "evalue", "bitscore", "positives"]
df = pd.read_csv("../output/structures/mRNA/blastp-hits.csv", header=None, names=colnames)
df = transform_df(df)

# %%
homologs = {}
guides = {}
for _, row in df.iterrows():
    print("Fetching", row.subject)
    with Entrez.efetch(
        db="protein", id=row.subject, rettype="gb", retmode="text"
    ) as handle:
        gb = handle.read()
    if not gb:
        print()
        continue
    if "/coded_by=" not in gb:
        print("No CDS region found for", row.subject)
        continue

    aa_rec = SeqIO.read(StringIO(gb), "genbank").format("fasta")
    aa_rec = SeqIO.read(StringIO(aa_rec), "fasta")
    if not aa_rec.seq:
        print("No sequence found for", row.subject)
        continue

    cds_coords = gb.split("/coded_by=")[1].split("\n")[0]
    if "(" in cds_coords:
        cds_coords = cds_coords.split("(")[-1].split(")")[0]
    seqid, coords = cds_coords.split(":")[0], cds_coords.split(":")[1]
    start, stop = coords.split("..")
    start = int("".join(filter(type(start).isdigit, start)))
    stop = int("".join(filter(type(stop).isdigit, stop)))
    seqid = "".join(c for c in seqid if c.isalnum() or c in "_.")
    if start > stop:
        start, stop = stop, start
    start -= 1
    print("Fetching CDS:", seqid, "for", row.subject)
    with Entrez.efetch(
        db="nucleotide", id=seqid, rettype="fasta", retmode="text"
    ) as handle:
        nn_rec = list(SeqIO.parse(handle, "fasta"))[0]
    nn_rec.seq = nn_rec.seq[start:stop]
    if not nn_rec.seq:
        print("No sequence found for", seqid)
        continue

    if row.query not in homologs:
        homologs[row.query] = [aa_rec]
    else:
        homologs[row.query] += [aa_rec]

    if row.query not in guides:
        guides[row.query] = [nn_rec]
    else:
        guides[row.query] += [nn_rec]
# Out:
# Fetching NP_009348.2
# Fetching CDS: NM_001178196.2 for NP_009348.2
# Fetching AJO92411.1
# Fetching CDS: CP004412.2 for AJO92411.1
# Fetching AHY74316.1
# Fetching CDS: CP004442.2 for AHY74316.1
# Fetching CAI4235603.1
# Fetching CDS: CANCKA010000001.1 for CAI4235603.1
# Fetching CAI4235905.1
# Fetching CDS: CANCVG010000001.1 for CAI4235905.1
# Fetching AJO92852.1
# Fetching CDS: CP004418.2 for AJO92852.1
# Fetching CAI7033446.1
# Fetching CDS: CASBNO010000001.1 for CAI7033446.1
# Fetching CAY77591.1
# Fetching CDS: FN393058.1 for CAY77591.1
# Fetching CAI4237633.1
# Fetching CDS: CANCBQ010000001.1 for CAI4237633.1
# Fetching PTN13517.1
# Fetching CDS: PTER01000024.1 for PTN13517.1
# Fetching AJQ14545.1
# Fetching CDS: CP004654.2 for AJQ14545.1
# Fetching AJP83910.1
# Fetching CDS: CP004573.2 for AJP83910.1
# Fetching CAI4256175.1
# Fetching CDS: CANCUJ010000002.1 for CAI4256175.1
# Fetching CAI6394045.1
# Fetching CDS: CASBIH010000012.1 for CAI6394045.1
# Fetching AJP86581.1
# ...

# %%
for query in homologs:
    try:
        with open(f"../output/structures/mRNA/{query}/seqdump_aa.txt", "w") as f:
            SeqIO.write(homologs[query], f, "fasta")
    except FileNotFoundError:
        continue

for query in guides:
    try:
        with open(f"../output/structures/mRNA/{query}/pal2nal_guides.txt", "w") as f:
            SeqIO.write(guides[query], f, "fasta")
    except FileNotFoundError:
        continue
