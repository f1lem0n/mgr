# %%
from Bio import Entrez, SeqIO
from io import StringIO

# %%
Entrez.email = "hajdylaf@gmail.com"

# %%
with open("../output_yeast_pre_threshold/structures/rRNA/blastn-hits.csv") as f:
    lines = f.readlines()
lines = [line.strip().split(",") for line in lines if line.strip()]

# %%
homologs = {}
for line in lines:
    query_id = line[0]
    subject_id = line[1]
    query_start = int(line[8]) - 1
    query_stop = int(line[9])
    print("Fetching", subject_id)
    with Entrez.efetch(db="nucleotide", id=subject_id, rettype="fasta", retmode="text") as handle:
        rec = list(SeqIO.parse(handle, "fasta"))[0]
    rec.seq = rec.seq[query_start:query_stop]
    if not rec.seq:
        print("No sequence found for", subject_id)
        continue
    if query_id not in homologs:
        homologs[query_id] = [rec]
    else:
        homologs[query_id] += [rec]
# Out:
# Fetching CP006315.2
# No sequence found for CP006315.2
# Fetching CP006305.2
# No sequence found for CP006305.2
# Fetching CP006295.2
# No sequence found for CP006295.2
# Fetching CP006285.2
# No sequence found for CP006285.2
# Fetching CP006275.2
# No sequence found for CP006275.2
# Fetching CP006355.2
# No sequence found for CP006355.2
# Fetching CP006335.2
# No sequence found for CP006335.2
# Fetching CP129570.1
# No sequence found for CP129570.1
# Fetching CP125416.1
# No sequence found for CP125416.1
# Fetching CP125399.1
# No sequence found for CP125399.1
# Fetching AP027353.1
# No sequence found for AP027353.1
# Fetching AP026841.1
# No sequence found for AP026841.1
# Fetching CP089109.1
# No sequence found for CP089109.1
# Fetching CP059531.2
# No sequence found for CP059531.2
# Fetching BK006943.2
# No sequence found for BK006943.2
# Fetching X85021.1
# No sequence found for X85021.1
# Fetching Z49379.1
# No sequence found for Z49379.1
# Fetching Z49378.1
# No sequence found for Z49378.1
# Fetching NR_132195.1
# Fetching CP092958.1
# Fetching CP005375.2
# Fetching CP005365.2
# Fetching CP005355.2
# Fetching CP005345.2
# Fetching CP005335.2
# Fetching CP005325.2
# Fetching CP005315.2
# Fetching CP005305.2
# Fetching CP129578.1
# Fetching CP080613.1
# Fetching CP005585.2
# Fetching CP005575.2
# Fetching CP005565.2
# Fetching CP005555.2
# Fetching CP005545.2
# Fetching CP005535.2
# Fetching CP129581.1
# Fetching CP125427.1
# Fetching CP125410.1
# Fetching CP080616.1
# Fetching CP008247.1
# Fetching CP008332.1
# Fetching CP008315.1
# Fetching CP008298.1
# Fetching CP008281.1
# Fetching CP008264.1
# Fetching CP008230.1
# Fetching CP008417.1
# Fetching CP008400.1
# Fetching CP129579.1
# Fetching CP008247.1
# No sequence found for CP008247.1
# Fetching CP008332.1
# No sequence found for CP008332.1
# Fetching CP008315.1
# No sequence found for CP008315.1
# Fetching CP008298.1
# No sequence found for CP008298.1
# Fetching CP008281.1
# No sequence found for CP008281.1
# Fetching CP008264.1
# No sequence found for CP008264.1
# Fetching CP129579.1
# No sequence found for CP129579.1
# Fetching CP125425.1
# No sequence found for CP125425.1
# Fetching CP125408.1
# No sequence found for CP125408.1
# Fetching CP080614.1
# No sequence found for CP080614.1
# Fetching CP005655.2
# Fetching CP005645.2
# Fetching CP005635.2
# Fetching CP005625.2
# Fetching CP005605.2
# Fetching CP005595.2
# Fetching CP008335.1
# Fetching CP008318.1
# Fetching CP129582.1
# Fetching CP080617.1
# Fetching CP005675.2
# Fetching CP005665.2
# Fetching CP005655.2
# Fetching CP005645.2
# Fetching CP005635.2
# Fetching CP005625.2
# Fetching CP129582.1
# Fetching CP125428.1
# Fetching CP125411.1
# Fetching CP080617.1

# %%
for query_id in homologs:
    with open(f"../output_yeast_pre_threshold/structures/rRNA/{query_id.upper()}/seqdump_nn.txt", "w") as f:
        SeqIO.write(homologs[query_id], f, "fasta")

# %%
with open("../output/structures/mRNA/blastp-hits.csv") as f:
    lines = f.readlines()
lines = [line.strip().split(",") for line in lines if line.strip()]

# %%
homologs = {}
guides = {}
for line in lines:
    query_id = line[0]
    subject_id = line[1]
    query_start = int(line[8]) - 1
    query_stop = int(line[9])

    print("Fetching", subject_id)
    with Entrez.efetch(
        db="protein", id=subject_id, rettype="gb", retmode="text"
    ) as handle:
        gb = handle.read()
    if not gb:
        print()
        continue
    if "/coded_by=" not in gb:
        print("No CDS region found for", subject_id)
        continue

    aa_rec = SeqIO.read(StringIO(gb), "genbank").format("fasta")
    aa_rec = SeqIO.read(StringIO(aa_rec), "fasta")
    if not aa_rec.seq:
        print("No sequence found for", subject_id)
        continue

    cds_coords = gb.split("/coded_by=")[1].split("\n")[0]
    if "(" in cds_coords:
        cds_coords = cds_coords.split("(")[-1].split(")")[0]
    seqid, coords = cds_coords.split(":")[0], cds_coords.split(":")[1]
    start, stop = coords.split("..")
    start = int("".join(filter(type(start).isdigit, start)))
    stop = int("".join(filter(type(stop).isdigit, stop)))
    seqid = "".join(c for c in seqid if c.isalnum() or c in "_.")
    if start > stop:
        start, stop = stop, start
    start -= 1
    print("Fetching CDS:", seqid, "for", subject_id)
    with Entrez.efetch(
        db="nucleotide", id=seqid, rettype="fasta", retmode="text"
    ) as handle:
        nn_rec = list(SeqIO.parse(handle, "fasta"))[0]
    nn_rec.seq = nn_rec.seq[start:stop]
    if not nn_rec.seq:
        print("No sequence found for", seqid)
        continue

    if query_id not in homologs:
        homologs[query_id] = [aa_rec]
    else:
        homologs[query_id] += [aa_rec]

    if query_id not in guides:
        guides[query_id] = [nn_rec]
    else:
        guides[query_id] += [nn_rec]
# Out:
# Fetching O13514.1
# No CDS region found for O13514.1
# Fetching KZV13421.1
# Fetching CDS: LBMA01000001.1 for KZV13421.1
# Fetching NP_009654.3
# Fetching CDS: NM_001178444.3 for NP_009654.3
# Fetching CAI4272395.1
# Fetching CDS: CANCRS010000002.1 for CAI4272395.1
# Fetching AJQ01256.1
# Fetching CDS: CP004619.1 for AJQ01256.1
# Fetching AJP87446.1
# Fetching CDS: CP004582.2 for AJP87446.1
# Fetching AJQ13484.1
# Fetching CDS: CP004651.2 for AJQ13484.1
# Fetching AJQ15779.1
# Fetching CDS: CP004657.2 for AJQ15779.1
# Fetching CAI7146735.1
# Fetching CDS: CASBOU010000002.1 for CAI7146735.1
# Fetching AJP98938.1
# Fetching CDS: CP004613.2 for AJP98938.1
# Fetching CAI4258547.1
# Fetching CDS: CANBTS010000002.1 for CAI4258547.1
# Fetching CAI4272761.1
# Fetching CDS: CANCBQ010000002.1 for CAI4272761.1
# Fetching NP_009846.1
# Fetching CDS: NM_001178635.1 for NP_009846.1
# Fetching AAT92609.1
# Fetching CDS: AY692590.1 for AAT92609.1
# Fetching AJP37359.1
# Fetching CDS: CP004100.2 for AJP37359.1
# Fetching CAI4293572.1
# Fetching CDS: CANCGP010000002.1 for CAI4293572.1
# Fetching AJQ01437.1
# Fetching CDS: CP004619.1 for AJQ01437.1
# Fetching CAI7161236.1
# Fetching CDS: CASBOY010000002.1 for CAI7161236.1
# Fetching CAI4293134.1
# Fetching CDS: CANCNU010000002.1 for CAI4293134.1
# Fetching AJQ14053.1
# Fetching CDS: CP004652.2 for AJQ14053.1
# Fetching AJQ00281.1
# Fetching CDS: CP004616.2 for AJQ00281.1
# Fetching CAI4924553.1
# Fetching CDS: CANCNF020000017.1 for CAI4924553.1
# Fetching NP_010280.1
# Fetching CDS: NM_001180063.1 for NP_010280.1
# Fetching CAI4327206.1
# Fetching CDS: CANCGT010000004.1 for CAI4327206.1
# Fetching AJU62713.1
# Fetching CDS: CP004667.2 for AJU62713.1
# Fetching CAI7067513.1
# Fetching CDS: CASBNK010000004.1 for CAI7067513.1
# Fetching CAD6608797.1
# Fetching CDS: LR813605.2 for CAD6608797.1
# Fetching EGA59490.1
# Fetching CDS: AEHH01000009.1 for EGA59490.1
# Fetching AJV07575.1
# Fetching CDS: CP004732.2 for AJV07575.1
# Fetching AJU88511.1
# Fetching CDS: CP004705.2 for AJU88511.1
# Fetching GMC21989.1
# Fetching CDS: BSXB01000135.1 for GMC21989.1
# Fetching CAI4336101.1
# Fetching CDS: CANCBQ010000004.1 for CAI4336101.1
# Fetching NP_010255.1
# Fetching CDS: NM_001180088.1 for NP_010255.1
# Fetching CAI4327814.1
# Fetching CDS: CANCIU010000004.1 for CAI4327814.1
# Fetching PTN15918.1
# Fetching CDS: PTER01000008.1 for PTN15918.1
# Fetching CAI4871970.1
# Fetching CDS: CANCVR010000004.1 for CAI4871970.1
# Fetching AJV13733.1
# Fetching CDS: CP004741.2 for AJV13733.1
# Fetching CAI5244837.1
# Fetching CDS: CANCQO030000009.1 for CAI5244837.1
# Fetching CAI4334002.1
# Fetching CDS: CANCUJ010000004.1 for CAI4334002.1
# Fetching XP_033765232.1
# Fetching CDS: XM_033909341.1 for XP_033765232.1
# Fetching EEU04954.1
# Fetching CDS: ACFL01000370.1 for EEU04954.1
# Fetching XP_056086643.1
# Fetching CDS: XM_056232356.1 for XP_056086643.1
# Fetching NP_010285.1
# Fetching CDS: NM_001180310.1 for NP_010285.1
# Fetching CAI4331158.1
# Fetching CDS: CANCDV010000004.1 for CAI4331158.1
# Fetching AJU80978.1
# Fetching CDS: CP004694.2 for AJU80978.1
# Fetching CAD6609570.1
# Fetching CDS: LR813588.2 for CAD6609570.1
# Fetching CAI5243663.1
# Fetching CDS: CANCFM030000008.1 for CAI5243663.1
# Fetching CAI4931975.1
# Fetching CDS: CANCGW020000011.1 for CAI4931975.1
# Fetching CAI5246516.1
# Fetching CDS: CANCIQ030000004.1 for CAI5246516.1
# Fetching AJU61307.1
# Fetching CDS: CP004665.2 for AJU61307.1
# Fetching CAI5051525.1
# Fetching CDS: CANCML020000052.1 for CAI5051525.1
# Fetching AJV13760.1
# Fetching CDS: CP004741.2 for AJV13760.1
# Fetching NP_010457.3
# Fetching CDS: NM_001180479.3 for NP_010457.3
# Fetching AAF99684.1
# Fetching CDS: AF263099.1 for AAF99684.1
# Fetching CAI4343017.1
# Fetching CDS: CANBMV010000004.1 for CAI4343017.1
# Fetching CAA68760.1
# Fetching CDS: Y00829.1 for CAA68760.1
# Fetching AAK26176.1
# Fetching CDS: AY028645.1 for AAK26176.1
# Fetching AFD29160.1
# Fetching CDS: JQ026177.1 for AFD29160.1
# Fetching CAI4348191.1
# Fetching CDS: CANCGT010000004.1 for CAI4348191.1
# Fetching AJV00682.1
# Fetching CDS: CP004722.2 for AJV00682.1
# Fetching CAI4907488.1
# Fetching CDS: CANCTU020000001.1 for CAI4907488.1
# Fetching EEU07818.1
# Fetching CDS: ACFL01000068.1 for EEU07818.1
# Fetching NP_001335758.1
# Fetching CDS: NM_001348813.1 for NP_001335758.1
# Fetching EGA75478.1
# Fetching CDS: ADVS01000014.1 for EGA75478.1
# Fetching EGA79400.1
# Fetching CDS: ADXC01000022.1 for EGA79400.1
# Fetching EHN07912.1
# Fetching CDS: AGVY01000013.1 for EHN07912.1
# Fetching EGA62964.1
# Fetching CDS: AEEZ01000018.1 for EGA62964.1
# Fetching EGA87464.1
# Fetching CDS: AEJS01000020.1 for EGA87464.1
# Fetching EGA83471.1
# Fetching CDS: ADVV01000021.1 for EGA83471.1
# Fetching NP_010938.1
# Fetching CDS: NM_001178912.1 for NP_010938.1
# Fetching CAI4418176.1
# Fetching CDS: CANBXQ010000006.1 for CAI4418176.1
# Fetching CAI4411394.1
# Fetching CDS: CANCKA010000006.1 for CAI4411394.1
# Fetching CAI4919222.1
# Fetching CDS: CANCMT020000011.1 for CAI4919222.1
# Fetching CAI4399544.1
# Fetching CDS: CANBMT010000006.1 for CAI4399544.1
# Fetching CAI4428659.1
# Fetching CDS: CANCRS010000006.1 for CAI4428659.1
# Fetching AJU53469.1
# Fetching CDS: CP004831.2 for AJU53469.1
# Fetching AJU44805.1
# Fetching CDS: CP004797.2 for AJU44805.1
# Fetching CAI4921883.1
# Fetching CDS: CANCML020000007.1 for CAI4921883.1
# Fetching CAD6621551.1
# Fetching CDS: LR813487.2 for CAD6621551.1
# Fetching NP_011447.1
# Fetching CDS: NM_001180933.1 for NP_011447.1
# Fetching CAD6625755.1
# Fetching CDS: LR813608.2 for CAD6625755.1
# Fetching EEU04979.1
# Fetching CDS: ACFL01000369.1 for EEU04979.1
# Fetching CAI4476649.1
# Fetching CDS: CANCOQ010000008.1 for CAI4476649.1
# Fetching CAI6514517.1
# Fetching CDS: CASBJG010000008.1 for CAI6514517.1
# Fetching AJR78531.1
# Fetching CDS: CP005199.1 for AJR78531.1
# Fetching AJS25258.1
# Fetching CDS: CP005253.2 for AJS25258.1
# Fetching KAF1908201.1
# Fetching CDS: JAAEAL010000004.1 for KAF1908201.1
# Fetching CAI4475610.1
# Fetching CDS: CANCBQ010000008.1 for CAI4475610.1
# Fetching AJR82982.1
# Fetching CDS: CP005208.2 for AJR82982.1
# Fetching NP_011380.3
# Fetching CDS: NM_001181000.3 for NP_011380.3
# Fetching XP_056087655.1
# Fetching CDS: XM_056227877.1 for XP_056087655.1
# Fetching CAI4830676.1
# Fetching CDS: CANCKW010000016.1 for CAI4830676.1
# Fetching XP_056085426.1
# Fetching CDS: XM_056231627.1 for XP_056085426.1
# Fetching XP_033766236.1
# Fetching CDS: XM_033910345.1 for XP_033766236.1
# Fetching CAI6818981.1
# Fetching CDS: CASBJT010000016.1 for CAI6818981.1
# Fetching CAI5269040.1
# Fetching CDS: CANCQQ030000060.1 for CAI5269040.1
# Fetching AJU23375.1
# Fetching CDS: CP006112.2 for AJU23375.1
# Fetching 7R7C_a
# No CDS region found for 7R7C_a
# Fetching GAA23261.1
# Fetching CDS: DG000043.1 for GAA23261.1
# Fetching NP_011671.3
# Fetching CDS: NM_001181284.3 for NP_011671.3
# Fetching CAI4496244.1
# Fetching CDS: CANCBQ010000008.1 for CAI4496244.1
# Fetching CAI6688448.1
# Fetching CDS: CASBKP010000008.1 for CAI6688448.1
# Fetching CAI4927388.1
# Fetching CDS: CANBQZ020000014.1 for CAI4927388.1
# Fetching ABD57960.1
# Fetching CDS: DQ393806.1 for ABD57960.1
# Fetching CAH1830281.1
# Fetching CDS: CAKOBR010000010.1 for CAH1830281.1
# Fetching AJS02904.1
# Fetching CDS: CP005272.2 for AJS02904.1
# Fetching CAI4482422.1
# Fetching CDS: CANBNW010000008.1 for CAI4482422.1
# Fetching BAA03952.1
# Fetching CDS: D16502.1 for BAA03952.1
# Fetching CAD6625055.1
# Fetching CDS: LR813557.2 for CAD6625055.1
# Fetching NP_012078.3
# Fetching CDS: NM_001179339.3 for NP_012078.3
# Fetching PTN19459.1
# Fetching CDS: PTEP01000023.1 for PTN19459.1
# Fetching CAI4918618.1
# Fetching CDS: CANBQZ020000008.1 for CAI4918618.1
# Fetching CAI4539862.1
# Fetching CDS: CANCSG010000009.1 for CAI4539862.1
# Fetching AJU27806.1
# Fetching CDS: CP006126.1 for AJU27806.1
# Fetching EWG90777.1
# Fetching CDS: KK037060.1 for EWG90777.1
# Fetching AHY77904.1
# Fetching CDS: CP006151.2 for AHY77904.1
# Fetching AJU22548.1
# Fetching CDS: CP006108.2 for AJU22548.1
# Fetching CAI4479973.1
# Fetching CDS: CANCGT010000008.1 for CAI4479973.1
# Fetching AJU21056.1
# Fetching CDS: CP006102.2 for AJU21056.1
# Fetching NP_012480.1
# Fetching CDS: NM_001181488.1 for NP_012480.1
# Fetching AJR73402.1
# Fetching CDS: CP005180.2 for AJR73402.1
# Fetching AHY78949.1
# Fetching CDS: CP005109.1 for AHY78949.1
# Fetching AJR75358.1
# Fetching CDS: CP005186.2 for AJR75358.1
# Fetching CAD6631312.1
# Fetching CDS: LR813492.2 for CAD6631312.1
# Fetching AJR54245.1
# Fetching CDS: CP005097.2 for AJR54245.1
# Fetching CAI5278743.1
# Fetching CDS: CANCPS030000010.1 for CAI5278743.1
# Fetching CAI4549618.1
# Fetching CDS: CANCFB010000010.1 for CAI4549618.1
# Fetching CAI4281601.1
# Fetching CDS: CANBSO010000003.1 for CAI4281601.1
# Fetching AJR65271.1
# Fetching CDS: CP005132.2 for AJR65271.1
# Fetching 4H86_A
# No CDS region found for 4H86_A
# Fetching NP_013210.1
# Fetching CDS: NM_001181996.1 for NP_013210.1
# Fetching 4OWY_A
# No CDS region found for 4OWY_A
# Fetching 4DSQ_A
# No CDS region found for 4DSQ_A
# Fetching CAD6636559.1
# Fetching CDS: LR813494.2 for CAD6636559.1
# Fetching AJV56967.1
# Fetching CDS: CP006401.1 for AJV56967.1
# Fetching CAD6635396.1
# Fetching CDS: LR813562.2 for CAD6635396.1
# Fetching CAI5292062.1
# Fetching CDS: CANCQQ030000098.1 for CAI5292062.1
# Fetching EGA57660.1
# Fetching CDS: AEHH01000050.1 for EGA57660.1
# Fetching CAI4630126.1
# Fetching CDS: CANCBN010000012.1 for CAI4630126.1
# Fetching 5VSU_G
# No CDS region found for 5VSU_G
# Fetching NP_014252.2
# Fetching CDS: NM_001182985.1 for NP_014252.2
# Fetching CAI4705832.1
# Fetching CDS: CANBMS010000014.1 for CAI4705832.1
# Fetching CAI5314449.1
# Fetching CDS: CANCIQ030000014.1 for CAI5314449.1
# Fetching QID81990.1
# Fetching CDS: CP048995.1 for QID81990.1
# Fetching PTN14122.1
# Fetching CDS: PTER01000017.1 for PTN14122.1
# Fetching CAI4979276.1
# Fetching CDS: CANCMT020000068.1 for CAI4979276.1
# Fetching AJT06849.1
# Fetching CDS: CP005508.2 for AJT06849.1
# Fetching CAI4701642.1
# Fetching CDS: CANBMT010000014.1 for CAI4701642.1
# Fetching AJT26624.1
# Fetching CDS: CP005562.2 for AJT26624.1
# Fetching CAI7330777.1
# Fetching CDS: CASBMT010000015.1 for CAI7330777.1
# Fetching NP_014593.1
# Fetching CDS: NM_001183303.1 for NP_014593.1
# Fetching CAI7460996.1
# Fetching CDS: CASBPB010000015.1 for CAI7460996.1
# Fetching CAI4774343.1
# Fetching CDS: CANCGT010000015.1 for CAI4774343.1
# Fetching CAI4918444.1
# Fetching CDS: CANCTQ020000027.1 for CAI4918444.1
# Fetching AJT73834.1
# Fetching CDS: CP005594.2 for AJT73834.1
# Fetching AJP41495.1
# Fetching CDS: CP004113.1 for AJP41495.1
# Fetching PTN18202.1
# Fetching CDS: PTER01000002.1 for PTN18202.1
# Fetching CAI4756371.1
# Fetching CDS: CANBTS010000015.1 for CAI4756371.1
# Fetching AJT98762.1
# Fetching CDS: CP005646.2 for AJT98762.1
# Fetching NP_014919.3
# Fetching CDS: NM_001183695.3 for NP_014919.3
# Fetching A6ZPB3.1
# No CDS region found for A6ZPB3.1
# Fetching CAI4748606.1
# Fetching CDS: CANBOS010000014.1 for CAI4748606.1
# Fetching CAI4775730.1
# Fetching CDS: CANBMW010000015.1 for CAI4775730.1
# Fetching AJT73631.1
# Fetching CDS: CP005593.1 for AJT73631.1
# Fetching CAI4809167.1
# Fetching CDS: CANCIU010000015.1 for CAI4809167.1
# Fetching CAI5339052.1
# Fetching CDS: CANCQR030000023.1 for CAI5339052.1
# Fetching CAI4946103.1
# Fetching CDS: CANCGW020000015.1 for CAI4946103.1
# Fetching AJP41785.1
# Fetching CDS: CP004113.1 for AJP41785.1
# Fetching CAI4788185.1
# Fetching CDS: CANBTS010000015.1 for CAI4788185.1
# Fetching NP_015244.1
# Fetching CDS: NM_001183895.1 for NP_015244.1
# Fetching CAI7381410.1
# Fetching CDS: CASBNG010000016.1 for CAI7381410.1
# Fetching CAI4831774.1
# Fetching CDS: CANCDV010000016.1 for CAI4831774.1
# Fetching CAD6651208.1
# Fetching CDS: LR813600.2 for CAD6651208.1
# Fetching AJV93610.1
# Fetching CDS: CP006205.2 for AJV93610.1
# Fetching AJW15126.1
# Fetching CDS: CP006164.2 for AJW15126.1
# Fetching 4U3M_S9
# No CDS region found for 4U3M_S9
# Fetching AJV98771.1
# Fetching CDS: CP006218.2 for AJV98771.1
# Fetching CAI4760949.1
# Fetching CDS: CANBPN010000015.1 for CAI4760949.1
# Fetching CAI4832926.1
# Fetching CDS: CANCBQ010000016.1 for CAI4832926.1
# Fetching NP_015182.1
# Fetching CDS: NM_001183957.1 for NP_015182.1
# Fetching XP_018218894.1
# Fetching CDS: XM_018368314.1 for XP_018218894.1
# Fetching NP_014877.3
# Fetching CDS: NM_001183653.3 for NP_014877.3
# Fetching XP_056085232.1
# Fetching CDS: XM_056231411.1 for XP_056085232.1
# Fetching CAI4771399.1
# Fetching CDS: CANBMW010000015.1 for CAI4771399.1
# Fetching 4U3M_O3
# No CDS region found for 4U3M_O3
# Fetching CAI5333623.1
# Fetching CDS: CANCVH030000015.1 for CAI5333623.1
# Fetching XP_056079646.1
# Fetching CDS: XM_056225871.1 for XP_056079646.1
# Fetching CAI4816664.1
# Fetching CDS: CANCRS010000015.1 for CAI4816664.1
# Fetching 6WOO_f
# No CDS region found for 6WOO_f

# %%
for query_id in homologs:
    try:
        with open(f"../output/structures/mRNA/{query_id}/seqdump_aa.txt", "w") as f:
            SeqIO.write(homologs[query_id], f, "fasta")
    except FileNotFoundError:
        continue
for query_id in guides:
    try:
        with open(f"../output/structures/mRNA/{query_id}/pal2nal_guides.txt", "w") as f:
            SeqIO.write(guides[query_id], f, "fasta")
    except FileNotFoundError:
        continue
